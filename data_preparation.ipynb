# %%
import os
import pandas as pd
from sklearn.preprocessing import OneHotEncoder,LabelEncoder

# %% [markdown]
# # Assembler les résultats des matches de tous les saisons

# %%
def concat_season():
    seasons=os.listdir(".")
    header=["Date","Time","Comp","Round","Day","Venue","Result","GF","GA","Opponent","Poss","Attendance","Captain","Formation","Referee","Match Report","Notes","team","season"]
    data=pd.DataFrame(columns=header)
    for season in seasons:
        if "-" in season:
            equipes=os.listdir(f"./{season}")
            for equipe in equipes:
                if "Stats" in equipe:
                    header=["Ast","PK","PKatt","Sh","SoT","CrdY","CrdR","Touches","Tkl","Int","Int","xG","npxG","xAG","SCA","GCA","Cmp","Att","Cmp%","PrgP","Carries","PrgC","Att","Succ"]
                    vals=[]
                    matchweeks=os.listdir(f"./{season}/{equipe}")
                    for matchweek in matchweeks:
                        summay=pd.read_csv(f"./{season}/{equipe}/{matchweek}/summary.csv")
                        vals.append(pd.array(summay.iloc[-1,7:]))
                    performence=pd.DataFrame(vals,columns=vals)
                    fils=pd.read_csv(f"./{season}/{equipe}/{equipe}.csv")
                    fils["team"]= " ".join(equipe.split("-")[:-1])
                    fils["season"]=season.split("-")[0]
                    data=pd.concat([data, fils], ignore_index=True)
    data.to_csv("dataset.csv")
    return data

# %%
data=concat_season()

# %%
data.head()
# Out:
#          Date Time            Comp        Round  Day Venue Result GF GA
# 0  2010-08-15  NaN  Premier League  Matchweek 1  Sun  Away      D  1  1  \
# 1  2010-08-21  NaN  Premier League  Matchweek 2  Sat  Home      W  6  0
# 2  2010-08-28  NaN  Premier League  Matchweek 3  Sat  Away      W  2  1
# 3  2010-09-11  NaN  Premier League  Matchweek 4  Sat  Home      W  4  1
# 4  2010-09-18  NaN  Premier League  Matchweek 5  Sat  Away      D  1  1
#
#      Opponent  ... Captain Formation          Referee
# 0   Liverpool  ...     NaN     4-5-1  Martin Atkinson  \
# 1   Blackpool  ...     NaN     4-3-3       Mike Jones
# 2   Blackburn  ...     NaN   4-2-3-1        Chris Foy
# 3      Bolton  ...     NaN     4-5-1   Stuart Attwell
# 4  Sunderland  ...     NaN   4-2-3-1        Phil Dowd
#
#                                         Match Report Notes     team season
# 0  https://fbref.com/en/matches/4d2dd8b3/Liverpoo...   NaN  Arsenal   2010  \
# 1  https://fbref.com/en/matches/9e517d4d/Arsenal-...   NaN  Arsenal   2010
# 2  https://fbref.com/en/matches/2b39e7c0/Blackbur...   NaN  Arsenal   2010
# 3  https://fbref.com/en/matches/8e9a6c63/Arsenal-...   NaN  Arsenal   2010
# 4  https://fbref.com/en/matches/66b3fe8e/Sunderla...   NaN  Arsenal   2010
#
#   Unnamed: 0  xG  xGA
# 0        0.0 NaN  NaN
# 1        1.0 NaN  NaN
# 2        2.0 NaN  NaN
# 3        3.0 NaN  NaN
# 4        5.0 NaN  NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# # Vérifier les valeurs manquants

# %%
data.isna().sum()
# Out:
# Date               0
# Time            3040
# Comp               0
# Round              0
# Day                0
# Venue              0
# Result             0
# GF                 0
# GA                 0
# Opponent           0
# Poss            3040
# Attendance       884
# Captain         3800
# Formation          0
# Referee            0
# Match Report       0
# Notes           9880
# team               0
# season             0
# Unnamed: 0         0
# xG              5320
# xGA             5320
# dtype: int64

# %%
data=data.drop(["Time","Comp","xG","xGA","Poss","Notes","Unnamed: 0"],axis=1)

# %% [markdown]
# # Encoder les carctérististiques non numérique

# %%
data["Date"]=pd.to_datetime(data["Date"])

# %%
data.dtypes
# Out:
# Date            datetime64[ns]
# Round                   object
# Day                     object
# Venue                   object
# Result                  object
# GF                      object
# GA                      object
# Opponent                object
# Attendance              object
# Captain                 object
# Formation               object
# Referee                 object
# Match Report            object
# team                    object
# season                  object
# dtype: object

# %%
data
# Out:
#            Date         Round  Day Venue Result GF GA        Opponent
# 0    2010-08-15   Matchweek 1  Sun  Away      D  1  1       Liverpool  \
# 1    2010-08-21   Matchweek 2  Sat  Home      W  6  0       Blackpool
# 2    2010-08-28   Matchweek 3  Sat  Away      W  2  1       Blackburn
# 3    2010-09-11   Matchweek 4  Sat  Home      W  4  1          Bolton
# 4    2010-09-18   Matchweek 5  Sat  Away      D  1  1      Sunderland
# ...         ...           ...  ...   ...    ... .. ..             ...
# 9875 2023-04-29  Matchweek 34  Sat  Away      L  0  6        Brighton
# 9876 2023-05-06  Matchweek 35  Sat  Home      W  1  0     Aston Villa
# 9877 2023-05-13  Matchweek 36  Sat  Away      L  0  2  Manchester Utd
# 9878 2023-05-20  Matchweek 37  Sat  Home      D  1  1         Everton
# 9879 2023-05-28  Matchweek 38  Sun  Away      L  0  5         Arsenal
#
#      Attendance      Captain Formation          Referee
# 0        44,722          NaN     4-5-1  Martin Atkinson  \
# 1        60,032          NaN     4-3-3       Mike Jones
# 2        25,059          NaN   4-2-3-1        Chris Foy
# 3        59,876          NaN     4-5-1   Stuart Attwell
# 4        38,950          NaN   4-2-3-1        Phil Dowd
# ...         ...          ...       ...              ...
# 9875     31,584  Rúben Neves     4-4-2      David Coote
# 9876     31,641  Rúben Neves     4-4-2   Stuart Attwell
# 9877     73,570  Rúben Neves     4-4-2      John Brooks
# 9878     31,684  Rúben Neves     4-4-2      David Coote
# 9879     60,095   Max Kilman     4-3-3   Andre Marriner
#
#                                            Match Report
# 0     https://fbref.com/en/matches/4d2dd8b3/Liverpoo...  \
# 1     https://fbref.com/en/matches/9e517d4d/Arsenal-...
# 2     https://fbref.com/en/matches/2b39e7c0/Blackbur...
# 3     https://fbref.com/en/matches/8e9a6c63/Arsenal-...
# 4     https://fbref.com/en/matches/66b3fe8e/Sunderla...
# ...                                                 ...
# 9875  https://fbref.com/en/matches/21f920e0/Brighton...
# 9876  https://fbref.com/en/matches/217a7faf/Wolverha...
# 9877  https://fbref.com/en/matches/f5d61382/Manchest...
# 9878  https://fbref.com/en/matches/ff2b58c3/Wolverha...
# 9879  https://fbref.com/en/matches/71d5bd41/Arsenal-...
#
#                          team season
# 0                     Arsenal   2010
# 1                     Arsenal   2010
# 2                     Arsenal   2010
# 3                     Arsenal   2010
# 4                     Arsenal   2010
# ...                       ...    ...
# 9875  Wolverhampton Wanderers   2022
# 9876  Wolverhampton Wanderers   2022
# 9877  Wolverhampton Wanderers   2022
# 9878  Wolverhampton Wanderers   2022
# 9879  Wolverhampton Wanderers   2022
#
# [9880 rows x 15 columns]

# %% [markdown]
# ### Venue

# %%
data["Venue_code"]=data["Venue"].astype("category").cat.codes

# %% [markdown]
# ### Resultat

# %%
resultat_encoder=LabelEncoder()
data["Result_code"]=resultat_encoder.fit_transform(data["Result"])

# %%
data.head(10)[["Result","Result_code"]]
# Out:
#   Result  Result_code
# 0      D            0
# 1      W            2
# 2      W            2
# 3      W            2
# 4      D            0
# 5      L            1
# 6      L            1
# 7      W            2
# 8      W            2
# 9      W            2

# %% [markdown]
# ### Round

# %%
round_encoder=LabelEncoder()
data["Round_code"]=round_encoder.fit_transform(data["Round"])

# %%
data.head(10)[["Round","Round_code"]]
# Out:
#           Round  Round_code
# 0   Matchweek 1           0
# 1   Matchweek 2          11
# 2   Matchweek 3          22
# 3   Matchweek 4          32
# 4   Matchweek 5          33
# 5   Matchweek 6          34
# 6   Matchweek 7          35
# 7   Matchweek 8          36
# 8   Matchweek 9          37
# 9  Matchweek 10           1

# %% [markdown]
# ### Formation

# %%
Formation_encoder=LabelEncoder()
data["Formation_code"]=Formation_encoder.fit_transform(data["Formation"])

# %%
data.head(76)[["Formation","Formation_code"]]
# Out:
#    Formation  Formation_code
# 0      4-5-1              19
# 1      4-3-3              16
# 2    4-2-3-1              12
# 3      4-5-1              19
# 4    4-2-3-1              12
# ..       ...             ...
# 71     4-4-2              18
# 72     4-4-2              18
# 73     4-4-2              18
# 74     4-5-1              19
# 75     4-5-1              19
#
# [76 rows x 2 columns]

# %% [markdown]
# ### Referee

# %%
Referee_encoder=LabelEncoder()
data["Referee_code"]=Referee_encoder.fit_transform(data["Referee"])

# %%
data[data["Referee"]=="Chris Foy"].head(76)[["Referee","Referee_code"]]
# Out:
#         Referee  Referee_code
# 2     Chris Foy             4
# 15    Chris Foy             4
# 25    Chris Foy             4
# 34    Chris Foy             4
# 62    Chris Foy             4
# ...         ...           ...
# 1160  Chris Foy             4
# 1169  Chris Foy             4
# 1183  Chris Foy             4
# 1194  Chris Foy             4
# 1211  Chris Foy             4
#
# [76 rows x 2 columns]

# %% [markdown]
# ### Day

# %%
data["Day_code"]=data["Date"].dt.dayofweek

# %%
data.head(10)
# Out:
#         Date         Round  Day Venue Result GF GA         Opponent
# 0 2010-08-15   Matchweek 1  Sun  Away      D  1  1        Liverpool  \
# 1 2010-08-21   Matchweek 2  Sat  Home      W  6  0        Blackpool
# 2 2010-08-28   Matchweek 3  Sat  Away      W  2  1        Blackburn
# 3 2010-09-11   Matchweek 4  Sat  Home      W  4  1           Bolton
# 4 2010-09-18   Matchweek 5  Sat  Away      D  1  1       Sunderland
# 5 2010-09-25   Matchweek 6  Sat  Home      L  2  3        West Brom
# 6 2010-10-03   Matchweek 7  Sun  Away      L  0  2          Chelsea
# 7 2010-10-16   Matchweek 8  Sat  Home      W  2  1  Birmingham City
# 8 2010-10-24   Matchweek 9  Sun  Away      W  3  0  Manchester City
# 9 2010-10-30  Matchweek 10  Sat  Home      W  1  0         West Ham
#
#   Attendance Captain  ...           Referee
# 0     44,722     NaN  ...   Martin Atkinson  \
# 1     60,032     NaN  ...        Mike Jones
# 2     25,059     NaN  ...         Chris Foy
# 3     59,876     NaN  ...    Stuart Attwell
# 4     38,950     NaN  ...         Phil Dowd
# 5     60,025     NaN  ...    Michael Oliver
# 6     41,828     NaN  ...         Mike Dean
# 7     60,070     NaN  ...   Martin Atkinson
# 8     47,393     NaN  ...  Mark Clattenburg
# 9     60,086     NaN  ...        Mike Jones
#
#                                         Match Report     team season
# 0  https://fbref.com/en/matches/4d2dd8b3/Liverpoo...  Arsenal   2010  \
# 1  https://fbref.com/en/matches/9e517d4d/Arsenal-...  Arsenal   2010
# 2  https://fbref.com/en/matches/2b39e7c0/Blackbur...  Arsenal   2010
# 3  https://fbref.com/en/matches/8e9a6c63/Arsenal-...  Arsenal   2010
# 4  https://fbref.com/en/matches/66b3fe8e/Sunderla...  Arsenal   2010
# 5  https://fbref.com/en/matches/2b9dadaa/Arsenal-...  Arsenal   2010
# 6  https://fbref.com/en/matches/a10d839a/North-We...  Arsenal   2010
# 7  https://fbref.com/en/matches/44dd7154/Arsenal-...  Arsenal   2010
# 8  https://fbref.com/en/matches/06943b36/Manchest...  Arsenal   2010
# 9  https://fbref.com/en/matches/2dc0c516/Arsenal-...  Arsenal   2010
#
#   Venue_code  Result_code  Round_code  Formation_code  Referee_code  Day_code
# 0          0            0           0              19            24         6
# 1          1            2          11              16            28         5
# 2          0            2          22              12             4         5
# 3          1            2          32              19            41         5
# 4          0            0          33              12            35         5
# 5          1            1          34              12            25         5
# 6          0            1          35              19            27         6
# 7          1            2          36              19            24         5
# 8          0            2          37              19            21         6
# 9          1            2           1              12            28         5
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Team and Opponent

# %%
data["team"]=data["team"].replace("Blackburn Rovers","Blackburn")
data["team"]=data["team"].replace("Bolton Wanderers","Bolton")
data["team"]=data["team"].replace("Manchester United","Manchester Utd")
data["team"]=data["team"].replace("Newcastle United","Newcastle Utd")
data["team"]=data["team"].replace("Tottenham Hotspur","Tottenham")
data["team"]=data["team"].replace("West Bromwich Albion","West Brom")
data["team"]=data["team"].replace("West Ham United","West Ham")
data["team"]=data["team"].replace("Wolverhampton Wanderers","Wolves")
data["team"]=data["team"].replace("Queens Park Rangers","QPR")
data["team"]=data["team"].replace("Brighton and Hove Albion","Brighton")
data["team"]=data["team"].replace("Huddersfield Town","Huddersfield")
data["team"]=data["team"].replace("Sheffield United","Sheffield Utd")
data["team"]=data["team"].replace("Nottingham Forest","Nott'ham Forest")

# %%
label_encoder = LabelEncoder()
data["Opponent_code"] = label_encoder.fit_transform(data["Opponent"])
data["team_code"] = label_encoder.transform(data["team"])

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## AVG G

# %%
matches_rolling_=data.copy()
win=matches_rolling_["Result_code"].replace([1,0],0)
win=win.replace(2,1)

# %%
matches_rolling_=data.copy()
lose=matches_rolling_["Result_code"].replace([0,2],0)

# %%
matches_rolling_=data.copy()
draw=matches_rolling_["Result_code"].replace([1,2],11)
draw=draw.replace(0,1)
draw=draw.replace(11,0)

# %%
data["win"]=win
data["draw"]=draw
data["lose"]=lose
data.head(10)
# Out:
#         Date         Round  Day Venue Result GF GA         Opponent
# 0 2010-08-15   Matchweek 1  Sun  Away      D  1  1        Liverpool  \
# 1 2010-08-21   Matchweek 2  Sat  Home      W  6  0        Blackpool
# 2 2010-08-28   Matchweek 3  Sat  Away      W  2  1        Blackburn
# 3 2010-09-11   Matchweek 4  Sat  Home      W  4  1           Bolton
# 4 2010-09-18   Matchweek 5  Sat  Away      D  1  1       Sunderland
# 5 2010-09-25   Matchweek 6  Sat  Home      L  2  3        West Brom
# 6 2010-10-03   Matchweek 7  Sun  Away      L  0  2          Chelsea
# 7 2010-10-16   Matchweek 8  Sat  Home      W  2  1  Birmingham City
# 8 2010-10-24   Matchweek 9  Sun  Away      W  3  0  Manchester City
# 9 2010-10-30  Matchweek 10  Sat  Home      W  1  0         West Ham
#
#   Attendance Captain  ... Result_code Round_code Formation_code Referee_code
# 0     44,722     NaN  ...           0          0             19           24  \
# 1     60,032     NaN  ...           2         11             16           28
# 2     25,059     NaN  ...           2         22             12            4
# 3     59,876     NaN  ...           2         32             19           41
# 4     38,950     NaN  ...           0         33             12           35
# 5     60,025     NaN  ...           1         34             12           25
# 6     41,828     NaN  ...           1         35             19           27
# 7     60,070     NaN  ...           2         36             19           24
# 8     47,393     NaN  ...           2         37             19           21
# 9     60,086     NaN  ...           2          1             12           28
#
#   Day_code  Opponent_code  team_code  win  draw  lose
# 0        6             19          0    0     1     0
# 1        5              4          0    1     0     0
# 2        5              3          0    1     0     0
# 3        5              5          0    1     0     0
# 4        5             31          0    0     1     0
# 5        5             35          0    0     0     1
# 6        6             11          0    0     0     1
# 7        5              2          0    1     0     0
# 8        6             20          0    1     0     0
# 9        5             36          0    1     0     0
#
# [10 rows x 26 columns]

# %% [markdown]
# ## Avr Goals

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
grouped_matches = data.groupby("team")

# %%
cols = ["GF", "GA","win","draw","lose"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
matches_rolling = data.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[260], line 1
# ----> 1 matches_rolling = data.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1353, in GroupBy.apply(self, func, *args, **kwargs)
#    1351 with option_context("mode.chained_assignment", None):
#    1352     try:
# -> 1353         result = self._python_apply_general(f, self._selected_obj)
#    1354     except TypeError:
#    1355         # gh-20949
#    1356         # try again, with .apply acting as a filtering
#    (...)
#    1360         # fails on *some* columns, e.g. a numeric operation
#    1361         # on a string grouper column
#    1363         return self._python_apply_general(f, self._obj_with_exclusions)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1367 @final
#    1368 def _python_apply_general(
#    1369     self,
#    (...)
#    1374     is_agg: bool = False,
#    1375 ) -> NDFrameT:
#    1376     """
#    1377     Apply function f in python space
#    1378
#    (...)
#    1400         data after applying f
#    1401     """
# -> 1402     values, mutated = self.grouper.apply(f, data, self.axis)
#    1403     if not_indexed_same is None:
#    1404         not_indexed_same = mutated
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:767, in BaseGrouper.apply(self, f, data, axis)
#     765 # group might be modified
#     766 group_axes = group.axes
# --> 767 res = f(group)
#     768 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     769     mutated = True
#
# Cell In[260], line 1, in <lambda>(x)
# ----> 1 matches_rolling = data.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#
# Cell In[257], line 3, in rolling_averages(group, cols, new_cols)
#       1 def rolling_averages(group, cols, new_cols):
#       2     group = group.sort_values("Date")
# ----> 3     rolling_stats = group[cols].rolling(3, closed='left').mean()
#       4     group[new_cols] = rolling_stats
#       5     group = group.dropna(subset=new_cols)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['win', 'draw', 'lose'] not in index"

# %%
matches_rolling
# Out:
#                    Date         Round  Day Venue Result GF GA
# team
# Arsenal 3    2010-09-11   Matchweek 4  Sat  Home      W  4  1  \
#         4    2010-09-18   Matchweek 5  Sat  Away      D  1  1
#         5    2010-09-25   Matchweek 6  Sat  Home      L  2  3
#         6    2010-10-03   Matchweek 7  Sun  Away      L  0  2
#         7    2010-10-16   Matchweek 8  Sat  Home      W  2  1
# ...                 ...           ...  ...   ...    ... .. ..
# Wolves  9875 2023-04-29  Matchweek 34  Sat  Away      L  0  6
#         9876 2023-05-06  Matchweek 35  Sat  Home      W  1  0
#         9877 2023-05-13  Matchweek 36  Sat  Away      L  0  2
#         9878 2023-05-20  Matchweek 37  Sat  Home      D  1  1
#         9879 2023-05-28  Matchweek 38  Sun  Away      L  0  5
#
#                      Opponent Attendance      Captain  ... Opponent_code
# team                                                   ...
# Arsenal 3              Bolton     59,876          NaN  ...             5  \
#         4          Sunderland     38,950          NaN  ...            31
#         5           West Brom     60,025          NaN  ...            35
#         6             Chelsea     41,828          NaN  ...            11
#         7     Birmingham City     60,070          NaN  ...             2
# ...                       ...        ...          ...  ...           ...
# Wolves  9875         Brighton     31,584  Rúben Neves  ...             8
#         9876      Aston Villa     31,641  Rúben Neves  ...             1
#         9877   Manchester Utd     73,570  Rúben Neves  ...            21
#         9878          Everton     31,684  Rúben Neves  ...            13
#         9879          Arsenal     60,095   Max Kilman  ...             0
#
#              team_code win draw lose  GF_rolling  GA_rolling  win_rolling
# team
# Arsenal 3            0   1    0    0    3.000000    0.666667     0.666667  \
#         4            0   0    1    0    4.000000    0.666667     1.000000
#         5            0   0    0    1    2.333333    1.000000     0.666667
#         6            0   0    0    1    2.333333    1.666667     0.333333
#         7            0   1    0    0    1.000000    2.000000     0.000000
# ...                ...  ..  ...  ...         ...         ...          ...
# Wolves  9875        38   0    0    1    1.666667    0.666667     0.666667
#         9876        38   1    0    0    1.000000    2.666667     0.333333
#         9877        38   0    0    1    1.000000    2.000000     0.666667
#         9878        38   0    1    0    0.333333    2.666667     0.333333
#         9879        38   0    0    1    0.666667    1.000000     0.333333
#
#               draw_rolling  lose_rolling
# team
# Arsenal 3         0.333333      0.000000
#         4         0.000000      0.000000
#         5         0.333333      0.000000
#         6         0.333333      0.333333
#         7         0.333333      0.666667
# ...                    ...           ...
# Wolves  9875      0.000000      0.333333
#         9876      0.000000      0.666667
#         9877      0.000000      0.333333
#         9878      0.000000      0.666667
#         9879      0.333333      0.333333
#
# [9763 rows x 31 columns]

# %%
matches_rolling[matches_rolling['team']=="Wolves"]
# Out:
#                   Date         Round  Day Venue Result GF GA        Opponent
# team
# Wolves 725  2010-09-11   Matchweek 4  Sat  Away      L  1  2          Fulham  \
#        726  2010-09-18   Matchweek 5  Sat  Away      L  1  3       Tottenham
#        727  2010-09-26   Matchweek 6  Sun  Home      L  1  2     Aston Villa
#        728  2010-10-02   Matchweek 7  Sat  Away      L  0  2  Wigan Athletic
#        729  2010-10-16   Matchweek 8  Sat  Home      D  1  1        West Ham
# ...                ...           ...  ...   ...    ... .. ..             ...
#        9875 2023-04-29  Matchweek 34  Sat  Away      L  0  6        Brighton
#        9876 2023-05-06  Matchweek 35  Sat  Home      W  1  0     Aston Villa
#        9877 2023-05-13  Matchweek 36  Sat  Away      L  0  2  Manchester Utd
#        9878 2023-05-20  Matchweek 37  Sat  Home      D  1  1         Everton
#        9879 2023-05-28  Matchweek 38  Sun  Away      L  0  5         Arsenal
#
#             Attendance      Captain  ... Opponent_code team_code win draw
# team                                 ...
# Wolves 725      25,280          NaN  ...            14        38   0    0  \
#        726      35,940          NaN  ...            33        38   0    0
#        727      27,511          NaN  ...             1        38   0    0
#        728      14,042          NaN  ...            37        38   0    0
#        729      28,582          NaN  ...            36        38   0    1
# ...                ...          ...  ...           ...       ...  ..  ...
#        9875     31,584  Rúben Neves  ...             8        38   0    0
#        9876     31,641  Rúben Neves  ...             1        38   1    0
#        9877     73,570  Rúben Neves  ...            21        38   0    0
#        9878     31,684  Rúben Neves  ...            13        38   0    1
#        9879     60,095   Max Kilman  ...             0        38   0    0
#
#             lose  GF_rolling  GA_rolling  win_rolling  draw_rolling
# team
# Wolves 725     1    1.333333    1.000000     0.333333      0.666667  \
#        726     1    1.000000    1.333333     0.000000      0.666667
#        727     1    1.000000    2.000000     0.000000      0.333333
#        728     1    1.000000    2.333333     0.000000      0.000000
#        729     0    0.666667    2.333333     0.000000      0.000000
# ...          ...         ...         ...          ...           ...
#        9875    1    1.666667    0.666667     0.666667      0.000000
#        9876    0    1.000000    2.666667     0.333333      0.000000
#        9877    1    1.000000    2.000000     0.666667      0.000000
#        9878    0    0.333333    2.666667     0.333333      0.000000
#        9879    1    0.666667    1.000000     0.333333      0.333333
#
#              lose_rolling
# team
# Wolves 725       0.000000
#        726       0.333333
#        727       0.666667
#        728       1.000000
#        729       1.000000
# ...                   ...
#        9875      0.333333
#        9876      0.666667
#        9877      0.333333
#        9878      0.666667
#        9879      0.333333
#
# [263 rows x 31 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.columns
# Out:
# Index(['Date', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA', 'Opponent',
#        'Attendance', 'Captain', 'Formation', 'Referee', 'Match Report', 'team',
#        'season', 'Venue_code', 'Result_code', 'Round_code', 'Formation_code',
#        'Referee_code', 'Day_code', 'Opponent_code', 'team_code', 'win', 'draw',
#        'lose', 'GF_rolling', 'GA_rolling', 'win_rolling', 'draw_rolling',
#        'lose_rolling'],
#       dtype='object')

# %%
matches_rolling
# Out:
#            Date         Round  Day Venue Result GF GA         Opponent
# 3    2010-09-11   Matchweek 4  Sat  Home      W  4  1           Bolton  \
# 4    2010-09-18   Matchweek 5  Sat  Away      D  1  1       Sunderland
# 5    2010-09-25   Matchweek 6  Sat  Home      L  2  3        West Brom
# 6    2010-10-03   Matchweek 7  Sun  Away      L  0  2          Chelsea
# 7    2010-10-16   Matchweek 8  Sat  Home      W  2  1  Birmingham City
# ...         ...           ...  ...   ...    ... .. ..              ...
# 9875 2023-04-29  Matchweek 34  Sat  Away      L  0  6         Brighton
# 9876 2023-05-06  Matchweek 35  Sat  Home      W  1  0      Aston Villa
# 9877 2023-05-13  Matchweek 36  Sat  Away      L  0  2   Manchester Utd
# 9878 2023-05-20  Matchweek 37  Sat  Home      D  1  1          Everton
# 9879 2023-05-28  Matchweek 38  Sun  Away      L  0  5          Arsenal
#
#      Attendance      Captain  ... Opponent_code team_code win draw lose
# 3        59,876          NaN  ...             5         0   1    0    0  \
# 4        38,950          NaN  ...            31         0   0    1    0
# 5        60,025          NaN  ...            35         0   0    0    1
# 6        41,828          NaN  ...            11         0   0    0    1
# 7        60,070          NaN  ...             2         0   1    0    0
# ...         ...          ...  ...           ...       ...  ..  ...  ...
# 9875     31,584  Rúben Neves  ...             8        38   0    0    1
# 9876     31,641  Rúben Neves  ...             1        38   1    0    0
# 9877     73,570  Rúben Neves  ...            21        38   0    0    1
# 9878     31,684  Rúben Neves  ...            13        38   0    1    0
# 9879     60,095   Max Kilman  ...             0        38   0    0    1
#
#       GF_rolling  GA_rolling  win_rolling  draw_rolling  lose_rolling
# 3       3.000000    0.666667     0.666667      0.333333      0.000000
# 4       4.000000    0.666667     1.000000      0.000000      0.000000
# 5       2.333333    1.000000     0.666667      0.333333      0.000000
# 6       2.333333    1.666667     0.333333      0.333333      0.333333
# 7       1.000000    2.000000     0.000000      0.333333      0.666667
# ...          ...         ...          ...           ...           ...
# 9875    1.666667    0.666667     0.666667      0.000000      0.333333
# 9876    1.000000    2.666667     0.333333      0.000000      0.666667
# 9877    1.000000    2.000000     0.666667      0.000000      0.333333
# 9878    0.333333    2.666667     0.333333      0.000000      0.666667
# 9879    0.666667    1.000000     0.333333      0.333333      0.333333
#
# [9763 rows x 31 columns]

# %%
dataCleaned=matches_rolling[["team_code","Opponent_code","season","Round_code","Venue_code","Referee_code","Formation_code","Day_code","GF_rolling","GA_rolling","win_rolling","draw_rolling","lose_rolling","Result_code"]]
dataCleaned.to_csv("dataCleaned.csv")

# %%
import pandas as pd
lis=[]
test=pd.read_csv("./2022-2023/Arsenal-Stats/Matchweek 1/summary.csv")

lis.append(pd.array(test.iloc[-1,7:]))

lis
# Out:
# [<PandasArray>
#  [   '1',    '1',    '0',    '0',   '10',    '2',    '2',    '0',  '599',
#     '29',    '9',   '17',  '1.0',  '1.0',  '0.6',   '18',    '2',  '378',
#    '469', '80.6',   '40',  '359',   '15',   '17',   '13']
#  Length: 25, dtype: object,
#  <PandasArray>
#  [   '1',    '1',    '0',    '0',   '10',    '2',    '2',    '0',  '599',
#     '29',    '9',   '17',  '1.0',  '1.0',  '0.6',   '18',    '2',  '378',
#    '469', '80.6',   '40',  '359',   '15',   '17',   '13']
#  Length: 25, dtype: object]
